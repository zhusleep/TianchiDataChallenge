# %%
# Out:
#                 xid           yid       date_id          hour          wind  \
# count  2.076372e+07  2.076372e+07  2.076372e+07  2.076372e+07  2.076372e+07
# mean   2.745000e+02  2.110000e+02  3.000000e+00  1.150000e+01           NaN
# std    1.581937e+02  1.215319e+02  1.414214e+00  5.188128e+00  0.000000e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  3.000000e+00  0.000000e+00
# 25%    1.377500e+02  1.060000e+02  2.000000e+00  7.000000e+00  8.773438e+00
# 50%    2.745000e+02  2.110000e+02  3.000000e+00  1.150000e+01  1.239844e+01
# 75%    4.112500e+02  3.160000e+02  4.000000e+00  1.600000e+01  1.570312e+01
# max    5.480000e+02  4.210000e+02  5.000000e+00  2.000000e+01  3.409375e+01
#
#            rainfall
# count  2.076372e+07
# mean            NaN
# std    0.000000e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    6.801758e-01
# max    2.310000e+02
#     xid  yid  date_id  hour       wind  rainfall
# ...

# %%
# Out:
# 20763720it [30:30, 11343.82it/s]

# %%
real_weather = pd.read_csv(real_weather_name,dtype=np.float16)

# %% [markdown]
# real_weather[de  ]
